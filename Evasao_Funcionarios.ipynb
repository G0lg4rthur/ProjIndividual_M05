# %% [markdown]
# <a href="https://colab.research.google.com/github/G0lg4rthur/ProjIndividual_M05/blob/main/Evasao_Funcionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Sobre os Dados

# %% [markdown]
# ### Dataset e Visualização Inicial
#
#  Neste projeto vamos explorar o seguinte dataset:
#
# ![image.png](data:image/png;base64,...)
#
# Esse conjunto de dados retrata a saída de funcionários de uma empresa, mostrando a quantidade desses e o motivo apresentado.
#
# * A coluna "HRBP" contém os resultados de uma pesquisa interna feita pelo setor de Recursos Humanos
# * A coluna "Exit Survey" contém os resultados de uma segunda pesquisa feita após a saída dos funcionários
# * A coluna "Ability to Impact" funciona como medida de valor para as saídas, criando contraste entre "HRBP" e "Exit Survey"
#
#
# ### Tambem nos foi disponibilizado uma visualização inicial:
#
# ![image.png](data:image/png;base64,...)
#
# #### Tal visualização possui alguns problemas:
# * O uso de bolhas dificulta uma leitura precisa dos dados;
# * Muita informação pode causar confusão ao ler;
# * A falta de alinhamento dos items por quantidade pode confundir o leitor;
#
# Estes apontamentos sobre esta visualização serão os norteadores na criação de nossos gráficos.

# %% [markdown]
# # Análise

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusões
