# %% [markdown]
# <a href="https://colab.research.google.com/github/G0lg4rthur/ProjIndividual_M05/blob/main/Evasao_Funcionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contexto
#   Neste projeto vamos explorar o seguinte dataset:
#
#
#   ![image.png](data:image/png;base64,...)
#
#   Esse conjunto de dados retrata a saída de funcionários de uma empresa, mostrando a quantidade desses e o motivo apresentado.
#   * A coluna "__HRBP__" contém os resultados de uma pesquisa interna feita pelo setor de Recursos Humanos
#   * A coluna "__Exit Survey__" contém os resultados de uma segunda pesquisa feita após a saída dos funcionários
#   * A coluna "__Ability to Impact__" funciona como medida de valor para as saídas, criando contraste entre "__HRBP__" e "__Exit Survey__"

# %% [markdown]
# ## Dados

# %% [markdown]
# # Análise

# %% [markdown]
# ## Conclusões
